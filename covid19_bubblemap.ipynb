# %% [markdown]
# <a href="https://colab.research.google.com/github/athanoid/pycovid19/blob/master/covid19_bubblemap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Bubble world map from COVID-19 datasets

Data Repository by Johns Hopkins CSSE: https://github.com/CSSEGISandData/COVID-19

@author: thanos
"""

import plotly.graph_objects as go
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df.head()

dates = list(df)
dates = dates[4:np.size(dates)]

# %%
fig = go.Figure()

for i in range(0,len(df)):
    fig.add_trace(go.Scattergeo(
            lon = np.array(df.iloc[i]['Long']),
            lat = np.array(df.iloc[i]['Lat']),
            text = np.array(df.iloc[i][dates[np.size(dates)-1]]),
            name = df.iloc[i]['Country/Region'],
            marker = dict(
                #change the bubble size based on value
                #size = np.array(df.iloc[i][dates[np.size(dates)-1]])/50,
                line_width = 0
            )))
    
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6278970c-3abd-4338-84f3-6de93a6f1d8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6278970c-3abd-4338-84f3-6de93a6f1d8b")) {
#                     Plotly.newPlot(
#                         '6278970c-3abd-4338-84f3-6de93a6f1d8b',
# ...
